# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1> My Jupyter Notebook (not) on IBM Watson Studio </h1>

# %% [markdown]
# <strong>Pierre Delzers</strong>

# %% [markdown]
# <body>Engineering Student</body>

# %% [markdown]
# <em>I'm interested in data science because I enjoy data mining and data visualization to study and quantify phenomenons</em>

# %% [markdown]
# <h3> This code calculates 1+1</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <ul>
#   <li>a</li>
#   <li>list</li>
# </ul>
#
#
# <table style="width:100%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#   </tr>
#   <tr>
#     <td>Pierre</td>
#     <td>Delzers</td>
#   </tr>
# </table>
#
# <a href="https://www.ibm.com/">IBM.com</a>
